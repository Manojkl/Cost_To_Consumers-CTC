# %%
! pip install genesis-world

# %%
import genesis as gs 

gs.generate("A water drops onto a beer bottle and slides slowly down the bottle surface")
# Out:
# [I 12/19/24 21:58:34.477 67934591] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout

# %%
import genesis as gs
print(dir(gs))
# gs.generate(
#     "A water drops onto a beer bottle and slides slowly down the bottle surface"
# )
# Out:
# ['ACTIVE', 'CTRL_MODE', 'Emitter', 'GEOM_TYPE', 'GS_ARCH', 'GenesisException', 'INACTIVE', 'IntEnum', 'JOINT_TYPE', 'List', 'Logger', 'Mesh', 'PARA_LEVEL', 'R_to_T', 'R_to_quat', 'Rotation', 'Scene', 'SpatialHasher', 'TI_ARCH', 'T_to_pos_lookat_up', 'Tensor', 'UID', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_custom_excepthook', '_display_greeting', '_globalize_backend', '_gs_exit', '_initialized', '_ti_outputs', 'arange', 'as_strided', 'as_tensor', 'asarray', 'assert_built', 'assert_initialized', 'assert_unbuilt', 'atexit', 'axis_angle_to_R', 'axis_angle_to_quat', 'backend', 'closest_segment_point', 'compute_camera_angle', 'constants', 'constraint_solver', 'cpu', 'cuda', 'datatypes', 'default_dofs_armature', 'default_dofs_damping', 'default_dofs_force_range', 'default_dofs_invweight', 'default_dofs_kp', 'default_dofs_kv', 'default_dofs_limit', 'default_dofs_motion_ang', 'default_dofs_motion_ve
# ...

# %%
a = [
    [
        "ACTIVE",
        "CTRL_MODE",
        "Emitter",
        "GEOM_TYPE",
        "GS_ARCH",
        "GenesisException",
        "INACTIVE",
        "IntEnum",
        "JOINT_TYPE",
        "List",
        "Logger",
        "Mesh",
        "PARA_LEVEL",
        "R_to_T",
        "R_to_quat",
        "Rotation",
        "Scene",
        "SpatialHasher",
        "TI_ARCH",
        "T_to_pos_lookat_up",
        "Tensor",
        "UID",
        "__builtins__",
        "__cached__",
        "__doc__",
        "__file__",
        "__loader__",
        "__name__",
        "__package__",
        "__path__",
        "__spec__",
        "__version__",
        "_custom_excepthook",
        "_display_greeting",
        "_globalize_backend",
        "_gs_exit",
        "_initialized",
        "_ti_outputs",
        "arange",
        "as_strided",
        "as_tensor",
        "asarray",
        "assert_built",
        "assert_initialized",
        "assert_unbuilt",
        "atexit",
        "axis_angle_to_R",
        "axis_angle_to_quat",
        "backend",
        "closest_segment_point",
        "compute_camera_angle",
        "constants",
        "constraint_solver",
        "cpu",
        "cuda",
        "datatypes",
        "default_dofs_armature",
        "default_dofs_damping",
        "default_dofs_force_range",
        "default_dofs_invweight",
        "default_dofs_kp",
        "default_dofs_kv",
        "default_dofs_limit",
        "default_dofs_motion_ang",
        "default_dofs_motion_vel",
        "default_dofs_stiffness",
        "default_friction",
        "default_solver_params",
        "destroy",
        "empty",
        "empty_like",
        "empty_strided",
        "engine",
        "euler_to_R",
        "euler_to_quat",
        "exit_callbacks",
        "ext",
        "eye",
        "fake_print",
        "first_init",
        "force_fields",
        "free_dofs_armature",
        "free_dofs_damping",
        "from_numpy",
        "from_torch",
        "full",
        "full_like",
        "get_cpu_device",
        "get_face_norm",
        "get_gpu_device",
        "get_platform",
        "global_scene_list",
        "gpu",
        "grad",
        "gs",
        "gs_backend",
        "identity_quat",
        "imp_aref",
        "inertial_mul",
        "init",
        "integrator",
        "inv_quat",
        "inv_transform_by_T",
        "inv_transform_by_quat",
        "inv_transform_by_trans_quat",
        "linspace",
        "logging",
        "logspace",
        "materials",
        "member",
        "metal",
        "morphs",
        "motion_cross_force",
        "motion_cross_motion",
        "name",
        "normalize",
        "nowhere",
        "np",
        "ones",
        "ones_like",
        "op",
        "opengl",
        "options",
        "orthogonals",
        "orthogonals2",
        "os",
        "patch",
        "pos_lookat_up_to_T",
        "quat_to_R",
        "quat_to_T",
        "quat_to_rotvec",
        "quat_to_xyz",
        "raise_exception",
        "rand",
        "rand_like",
        "randint",
        "randint_like",
        "randn",
        "randn_like",
        "random_quaternion",
        "randperm",
        "range",
        "renderers",
        "repr_base",
        "rotvec_to_R",
        "rotvec_to_quat",
        "scale_to_T",
        "set_random_seed",
        "set_verbose",
        "slerp",
        "states",
        "styles",
        "surfaces",
        "sys",
        "tc_identity_quat",
        "tc_zero_pos",
        "tensor",
        "textures",
        "ti",
        "ti_R_to_xyz",
        "ti_identity_quat",
        "ti_inv_quat",
        "ti_inv_transform_by_T",
        "ti_inv_transform_by_quat",
        "ti_inv_transform_by_trans_quat",
        "ti_inv_transform_motion_by_trans_quat",
        "ti_normalize",
        "ti_nowhere",
        "ti_quat_to_R",
        "ti_quat_to_T",
        "ti_quat_to_rotvec",
        "ti_quat_to_xyz",
        "ti_rotvec_to_R",
        "ti_rotvec_to_quat",
        "ti_tet_vol",
        "ti_trans_quat_to_T",
        "ti_trans_to_T",
        "ti_transform_by_T",
        "ti_transform_by_quat",
        "ti_transform_by_trans_quat",
        "ti_transform_inertia_by_trans_quat",
        "ti_transform_motion_by_trans_quat",
        "ti_transform_pos_quat_by_trans_quat",
        "ti_transform_quat_by_quat",
        "ti_vec3",
        "ti_xyz_to_quat",
        "tools",
        "torch",
        "torch_op_wrapper",
        "traceback",
        "trans_R_to_T",
        "trans_quat_to_T",
        "trans_to_T",
        "transform_by_R",
        "transform_by_T",
        "transform_by_quat",
        "transform_by_quat_yaw",
        "transform_by_trans_quat",
        "transform_by_xyz",
        "transform_inertia_by_T",
        "transform_pos_quat_by_trans_quat",
        "transform_quat_by_quat",
        "utils",
        "version",
        "vis",
        "vulkan",
        "wxyz_to_xyzw",
        "xyz_to_quat",
        "xyzw_to_wxyz",
        "z_to_R",
        "z_up_to_R",
        "zero_pos",
        "zeros",
        "zeros_like",
    ]
]
